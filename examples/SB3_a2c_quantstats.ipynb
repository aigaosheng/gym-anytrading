# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import gymnasium as gym
import gym_anytrading
from gym_anytrading.envs import Actions

from stable_baselines3 import A2C

import quantstats as qs

# %% [markdown]
# ### Create Env

# %%
# df = gym_anytrading.datasets.STOCKS_GOOGL.copy()
import pandas_ta as ta
df = pd.DataFrame().ta.ticker('AAPL', start='2020-01-01', end='2025-05-23')
df = df.rename(columns={'open': 'Open', 'high': 'High', 'low': 'Low', 'close': 'Close', 'volume': 'Volume'})
df['Date'] = pd.to_datetime(df.index)
df = df.set_index('Date')

window_size = 60
start_index = window_size
end_index = len(df)

env = gym.make(
    'stocks-v0',
    df=df,
    window_size=window_size,
    frame_bound=(start_index, end_index),
    max_episode_steps = 100_000,  # Set a high limit for max steps
)

print("observation_space:", env.observation_space)
# Out:
# YF deprecation warning: set proxy via new config function: yf.set_config(proxy=proxy)
# ---------------------------------------------------------------------------
# NameNotFound                              Traceback (most recent call last)
# Cell In[3], line 12
#       9 start_index = window_size
#      10 end_index = len(df)
# ---> 12 env = gym.make(
#      13     'stock', #'stocks-v0',
#      14     df=df,
#      15     window_size=window_size,
#      16     frame_bound=(start_index, end_index),
#      17     max_episode_steps = 100_000,  # Set a high limit for max steps
#      18 )
#      20 print("observation_space:", env.observation_space)
#
# File ~/work/Gymnasium/gymnasium/envs/registration.py:689, in make(id, max_episode_steps, disable_env_checker, **kwargs)
#     686     assert isinstance(id, str)
#     688     # The environment name can include an unloaded module in "module:env_name" style
# --> 689     env_spec = _find_spec(id)
#     691 assert isinstance(env_spec, EnvSpec)
#     693 # Update the env spec kwargs with the `make` kwargs
#
# File ~/work/Gymnasium/gymnasium/envs/registration.py:533, in _find_spec(env_id)
#     527     logger.warn(
#     528         f"Using the latest versioned environment `{new_env_id}` "
#     529         f"instead of the unversioned environment `{env_name}`."
#     530     )
#     532 if env_spec is None:
# --> 533     _check_version_exists(ns, name, version)
#     534     raise error.Error(
#     535         f"No registered env with id: {env_name}. Did you register it, or import the package that registers it? Use `gymnasium.pprint_registry()` to see all of the registered environments."
#     536     )
#     538 return env_spec
#
# File ~/work/Gymnasium/gymnasium/envs/registration.py:399, in _check_version_exists(ns, name, version)
#     396 if get_env_id(ns, name, version) in registry:
#     397     return
# --> 399 _check_name_exists(ns, name)
#     400 if version is None:
#     401     return
#
# File ~/work/Gymnasium/gymnasium/envs/registration.py:376, in _check_name_exists(ns, name)
#     373 namespace_msg = f" in namespace {ns}" if ns else ""
#     374 suggestion_msg = f" Did you mean: `{suggestion[0]}`?" if suggestion else ""
# --> 376 raise error.NameNotFound(
#     377     f"Environment `{name}` doesn't exist{namespace_msg}.{suggestion_msg}"
#     378 )
#
# NameNotFound: Environment `stock` doesn't exist. Did you mean: `stocks`?

# %%
df.head(2)
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2020-01-02 00:00:00-05:00  71.627077  72.681274  71.373203  72.620827
# 2020-01-03 00:00:00-05:00  71.847110  72.676439  71.689950  71.914810
#
#                               Volume  Dividends  Stock Splits
# Date
# 2020-01-02 00:00:00-05:00  135480400        0.0           0.0
# 2020-01-03 00:00:00-05:00  146322800        0.0           0.0

# %% [markdown]
# ### Train Env

# %%
env.reset(seed=2023)
model = A2C('MlpPolicy', env, verbose=0)
model.learn(total_timesteps=1_0_000, progress_bar=True)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %% [markdown]
# ### Test Env

# %%
action_stats = {Actions.Sell: 0, Actions.Buy: 0}

observation, info = env.reset(seed=2023)

while True:
    # action = env.action_space.sample()
    action, _states = model.predict(observation)

    action_stats[Actions(action)] += 1
    observation, reward, terminated, truncated, info = env.step(action)
    done = terminated or truncated

    # env.render()
    if done:
        break

env.close()

print("action_stats:", action_stats)
print("info:", info)
# Out:
# action_stats: {<Actions.Sell: 0>: 670, <Actions.Buy: 1>: 624}
# info: {'total_reward': np.float32(68.78416), 'total_profit': np.float32(0.013379144), 'position': <Positions.Long: 1>}

# %% [markdown]
# ### Plot Results

# %%
plt.figure(figsize=(16, 6))
env.unwrapped.render_all()
plt.show()

# %% [markdown]
# ### Analysis Using `quantstats`

# %%
qs.extend_pandas()

net_worth = pd.Series(env.unwrapped.history['total_profit'], index=df.index[start_index+1:end_index])
returns = net_worth.pct_change().iloc[1:]

qs.reports.full(returns)
qs.reports.html(returns, output='SB3_a2c_quantstats.html')
# Out:
# <h4>Performance Metrics</h4>
#                            Strategy
# -------------------------  ----------
# Start Period               2020-04-01
# End Period                 2025-05-22
# Risk-Free Rate             0.0%
# Time in Market             25.0%
#
# Cumulative Return          -98.66%
# CAGR﹪                     -43.96%
#
# Sharpe                     -3.57
# Prob. Sharpe Ratio         0.0%
# Smart Sharpe               -3.4
# Sortino                    -3.9
# Smart Sortino              -3.71
# Sortino/√2                 -2.76
# Smart Sortino/√2           -2.62
# Omega                      0.26
#
# Max Drawdown               -98.73%
# Longest DD Days            1862
# Volatility (ann.)          22.76%
# Calmar                     -0.45
# Skew                       -1.74
# Kurtosis                   14.95
#
# Expected Daily %           -0.33%
# Expected Monthly %         -6.72%
# Expected Yearly %          -51.28%
# Kelly Criterion            -75.58%
# Risk of Ruin               0.0%
# Daily Value-at-Risk        -2.68%
# Expected Shortfall (cVaR)  -2.68%
#
# Max Consecutive Wins       1
# Max Consecutive Losses     1
# Gain/Pain Ratio            -0.74
# Gain/Pain (1M)             -0.96
#
# Payoff Ratio               0.72
# Profit Factor              0.26
# Common Sense Ratio         0.03
# CPC Index                  0.05
# Tail Ratio                 0.13
# Outlier Win Ratio          25.53
# Outlier Loss Ratio         2.24
#
# MTD                        -4.68%
# 3M                         -30.3%
# 6M                         -33.41%
# YTD                        -32.7%
# 1Y                         -54.64%
# 3Y (ann.)                  -44.61%
# 5Y (ann.)                  -44.61%
# 10Y (ann.)                 -43.96%
# All-time (ann.)            -43.96%
#
# Best Day                   9.58%
# Worst Day                  -11.26%
# Best Month                 3.36%
# Worst Month                -21.82%
# Best Year                  -32.7%
# Worst Year                 -72.85%
#
# Avg. Drawdown              -98.73%
# Avg. Drawdown Days         1862
# Recovery Factor            4.22
# Ulcer Index                0.8
# Serenity Index             -0.06
#
# Avg. Up Month              1.71%
# Avg. Down Month            -7.78%
# Win Days %                 26.27%
# Win Month %                12.9%
# Win Quarter %              0.0%
# Win Year %                 0.0%
# None
# <h4 style="margin-bottom:20px">Worst 5 Drawdowns</h4>
#         Start      Valley         End  Days  Max Drawdown  99% Max Drawdown
# 1  2020-04-17  2025-05-22  2025-05-22  1862     -98.72586        -98.658859
# <h4>Strategy Visualization</h4>
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# /home/gs/miniconda3/envs/rl/lib/python3.12/site-packages/quantstats/_plotting/core.py:1016: ChainedAssignmentError: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# When using the Copy-on-Write mode, such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object.
#
#
#   port["Weekly"].ffill(inplace=True)
# /home/gs/miniconda3/envs/rl/lib/python3.12/site-packages/quantstats/_plotting/core.py:1019: ChainedAssignmentError: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# When using the Copy-on-Write mode, such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object.
#
#
#   port["Monthly"].ffill(inplace=True)
# /home/gs/miniconda3/envs/rl/lib/python3.12/site-packages/quantstats/_plotting/core.py:1022: ChainedAssignmentError: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# When using the Copy-on-Write mode, such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object.
#
#
#   port["Quarterly"].ffill(inplace=True)
# /home/gs/miniconda3/envs/rl/lib/python3.12/site-packages/quantstats/_plotting/core.py:1025: ChainedAssignmentError: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# When using the Copy-on-Write mode, such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object.
#
#
#   port["Yearly"].ffill(inplace=True)
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# /home/gs/miniconda3/envs/rl/lib/python3.12/site-packages/quantstats/_plotting/core.py:1016: ChainedAssignmentError: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# When using the Copy-on-Write mode, such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object.
#
#
#   port["Weekly"].ffill(inplace=True)
# /home/gs/miniconda3/envs/rl/lib/python3.12/site-packages/quantstats/_plotting/core.py:1019: ChainedAssignmentError: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# When using the Copy-on-Write mode, such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object.
#
#
#   port["Monthly"].ffill(inplace=True)
# /home/gs/miniconda3/envs/rl/lib/python3.12/site-packages/quantstats/_plotting/core.py:1022: ChainedAssignmentError: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# When using the Copy-on-Write mode, such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object.
#
#
#   port["Quarterly"].ffill(inplace=True)
# /home/gs/miniconda3/envs/rl/lib/python3.12/site-packages/quantstats/_plotting/core.py:1025: ChainedAssignmentError: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# When using the Copy-on-Write mode, such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object.
#
#
#   port["Yearly"].ffill(inplace=True)
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
